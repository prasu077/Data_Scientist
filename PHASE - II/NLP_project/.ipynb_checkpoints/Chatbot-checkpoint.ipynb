# %%
import json
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense, Dropout
from tensorflow.keras.utils import to_categorical

# %%
with open("intentsnew.json", "r") as file:
    data = json.load(file)

print("Total Intents:", len(data["intents"]))
# Out:
# Total Intents: 41

# %%
patterns = []
tags = []

for intent in data["intents"]:
    tag = intent["tag"]

    for pattern in intent["patterns"]:
        patterns.append(pattern)
        tags.append(tag)

print("Total Patterns:", len(patterns))
print("Total Tags:", len(tags))
# Out:
# Total Patterns: 10248
# Total Tags: 10248

# %%
encoder = LabelEncoder()

y = encoder.fit_transform(tags)

print("Number of Classes:", len(encoder.classes_))
print(encoder.classes_)
# Out:
# Number of Classes: 41
# ['Eligibility Criteria' 'FMCIII' 'Steps to complete the admission' 'about'
#  'canteen' 'clubs' 'college intake' 'computerhod' 'course' 'creator'
#  'cutoff' 'document' 'event' 'extchod' 'facilities' 'fees' 'floors'
#  'goodbye' 'greeting' 'hostel' 'hours' 'infrastructure' 'ithod' 'library'
#  'location' 'menu' 'name' 'number' 'placement' 'principal' 'ragging'
#  'random' 'salutaion' 'scholarship' 'sports' 'swear' 'syllabus' 'task'
#  'trust' 'uniform' 'vacation']

# %%
X_train, X_test, y_train, y_test = train_test_split(
    patterns,
    y,
    test_size=0.2,
    random_state=42,
    stratify=y
)

print("Train Size:", len(X_train))
print("Test Size:", len(X_test))
# Out:
# Train Size: 8198
# Test Size: 2050

# %%
tokenizer = Tokenizer(oov_token="<OOV>")

tokenizer.fit_on_texts(X_train)

vocab_size = len(tokenizer.word_index) + 1

print("Vocabulary Size:", vocab_size)
# Out:
# Vocabulary Size: 333

# %%
print(tokenizer.word_index)
# Out:
# {'<OOV>': 1, 'information': 2, 'about': 3, 'you': 4, 'can': 5, 'explain': 6, 'details': 7, 'tell': 8, 'me': 9, 'related': 10, 'question': 11, 'query': 12, 'need': 13, 'regarding': 14, 'help': 15, '22': 16, '28': 17, '24': 18, '5': 19, '25': 20, '21': 21, '27': 22, '16': 23, '2': 24, '14': 25, '17': 26, '6': 27, '10': 28, '23': 29, '12': 30, '18': 31, '15': 32, '8': 33, '4': 34, '26': 35, '11': 36, '3': 37, '9': 38, '1': 39, '7': 40, 'college': 41, '19': 42, '29': 43, '13': 44, '30': 45, '20': 46, 'the': 47, 'hostel': 48, 'name': 49, 'fees': 50, 'admission': 51, 'number': 52, 'cutoff': 53, 'to': 54, 'canteen': 55, 'library': 56, 'facilities': 57, 'ragging': 58, 'sports': 59, 'trust': 60, 'principal': 61, 'uniform': 62, 'syllabus': 63, 'fmciii': 64, 'clubs': 65, 'infrastructure': 66, 'floors': 67, 'event': 68, 'scholarship': 69, 'menu': 70, 'eligibility': 71, 'placement': 72, 'document': 73, 'steps': 74, 'hours': 75, 'criteria': 76, 'goodbye': 77, 'intake': 78, 'random': 79, 'vacation': 80, 'computerhod': 81, 'creator': 82, 'greeting': 83, 'swear': 84, 'location': 85, 'ithod': 86, 'complete': 87, 'extchod': 88, 'task': 89, 'salutaion': 90, 'course': 91, 'is': 92, 'what': 93, 'of': 94, 'are': 95, 'in': 96, 'for': 97, 'how': 98, 'i': 99, 'who': 100, 'your': 101, 'where': 102, 'hod': 103, 'do': 104, 'courses': 105, 'have': 106, 'documents': 107, 'does': 108, 'facility': 109, 'there': 110, 'fee': 111, 'it': 112, 'when': 113, 'uni': 114, 'any': 115, 'list': 116, 'computer': 117, 'address': 118, 'available': 119, 'events': 120, 'something': 121, 'timing': 122, 'required': 123, 'holidays': 124, 'developers': 125, 'offered': 126, 'branches': 127, 'engineering': 128, 'ac': 129, 'room': 130, 'good': 131, 'contact': 132, 'info': 133, 'a': 134, 'get': 135, 'at': 136, 'semester': 137, 'and': 138, 'extc': 139, 'seats': 140, 'which': 141, 'companies': 142, 'score': 143, 'much': 144, 'provide': 145, 'give': 146, 'technology': 147, 'this': 148, 'activities': 149, 'should': 150, 'located': 151, 'we': 152, 'food': 153, 'distance': 154, 'each': 155, 'will': 156, 'many': 157, 'size': 158, 'maximum': 159, 'students': 160, 'visit': 161, 'guys': 162, 'open': 163, 'accept': 164, 'mechanical': 165, 'see': 166, 'thanks': 167, 'ok': 168, 'needed': 169, 'admision': 170, 'work': 171, 'antiragging': 172, 'up': 173, 'building': 174, 'love': 175, 'bring': 176, 'made': 177, 'short': 178, 'am': 179, 'say': 180, 'no': 181, 'u': 182, 'step': 183, 'by': 184, 'procedure': 185, 'call': 186, 'on': 187, 'creators': 188, 'created': 189, 'year': 190, 'between': 191, 'wear': 192, 'later': 193, 'books': 194, 'phone': 195, 'co': 196, 'reach': 197, 'process': 198, 'done': 199, 'whats': 200, 'per': 201, 'branch': 202, 'day': 203, 'games': 204, 'holiday': 205, 'time': 206, 'idiot': 207, 'create': 208, 'got': 209, 'go': 210, 'campus': 211, 'cya': 212, 'capacity': 213, 'during': 214, 'bye': 215, 'cet': 216, 'designed': 217, 'fuck': 218, 'artificial': 219, 'intelligence': 220, 'asshole': 221, 'scholarships': 222, 'its': 223, "what's": 224, 'tall': 225, "uni's": 226, 'flowchart': 227, 'chatting': 228, 'thing': 229, 'hi': 230, 'nice': 231, 'thank': 232, 'wheres': 233, 'offer': 234, 'working': 235, 'days': 236, 'dresscode': 237, 'tihe': 238, 'general': 239, "principal's": 240, 'office': 241, 'cases': 242, 'attend': 243, 'entc': 244, 'okay': 245, 'book': 246, 'foods': 247, 'practice': 248, 'active': 249, 'recruitment': 250, 'fmcii': 251, 'non': 252, 'down': 253, 'called': 254, 'saturday': 255, 'anyone': 256, 'boys': 257, 'gtg': 258, 'stupid': 259, 'aids': 260, 'held': 261, 'fucker': 262, 'max': 263, 'hello': 264, 'end': 265, 'why': 266, 'use': 267, 'juniors': 268, 'telephone': 269, 'operation': 270, 'incidents': 271, 'curricualr': 272, 'variety': 273, 'department': 274, 'against': 275, 'servive': 276, 'here': 277, 'talk': 278, 'cafetaria': 279, 'ai': 280, 'ml': 281, 'eat': 282, 'shut': 283, 'far': 284, 'from': 285, 'conducted': 286, 'timetable': 287, 'job': 288, 'long': 289, 'be': 290 ...

# %%
X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)

# %%
max_length = max(len(seq) for seq in X_train_seq)

X_train_pad = pad_sequences(
    X_train_seq,
    maxlen=max_length,
    padding="post"
)

X_test_pad = pad_sequences(
    X_test_seq,
    maxlen=max_length,
    padding="post"
)

print("Max Length:", max_length)
print("Classes:", len(encoder.classes_))
# Out:
# Max Length: 9
# Classes: 41

# %%
from tensorflow.keras.utils import to_categorical

y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)

print(y_train_cat.shape)
print(y_test_cat.shape)
# Out:
# (8198, 41)
# (2050, 41)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dense, Dropout

model = Sequential([
    
    Embedding(
        input_dim=vocab_size,
        output_dim=64,
        input_length=max_length
    ),

    GRU(128),

    Dropout(0.3),

    Dense(64, activation="relu"),

    Dense(41, activation="softmax")
])

model.summary()
# Out:
# C:\Users\prasa\OneDrive\Desktop\Data_Scientist\PHASE - II\tfenv\Lib\site-packages\keras\src\layers\core\embedding.py:103: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)                │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ gru (GRU)                            │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ ?                           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ ?                           │     0 (unbuilt) │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ ?                           │     0 (unbuilt) │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer="adam",
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
history = model.fit(
    X_train_pad,
    y_train_cat,
    epochs=50,
    batch_size=8,
    validation_data=(X_test_pad, y_test_cat)
)
# Out:
# Epoch 1/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 31s 19ms/step - accuracy: 0.2038 - loss: 2.4579 - val_accuracy: 0.4044 - val_loss: 1.5334
# Epoch 2/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.6564 - loss: 1.0237 - val_accuracy: 0.7912 - val_loss: 0.6106
# Epoch 3/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 17s 17ms/step - accuracy: 0.9427 - loss: 0.3205 - val_accuracy: 0.9795 - val_loss: 0.1597
# Epoch 4/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.9741 - loss: 0.1569 - val_accuracy: 0.9790 - val_loss: 0.1494
# Epoch 5/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9763 - loss: 0.1219 - val_accuracy: 0.9849 - val_loss: 0.1214
# Epoch 6/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.9823 - loss: 0.0898 - val_accuracy: 0.9859 - val_loss: 0.1107
# Epoch 7/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.9829 - loss: 0.0736 - val_accuracy: 0.9859 - val_loss: 0.1156
# Epoch 8/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.9857 - loss: 0.0582 - val_accuracy: 0.9849 - val_loss: 0.1126
# Epoch 9/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 17s 17ms/step - accuracy: 0.9885 - loss: 0.0504 - val_accuracy: 0.9883 - val_loss: 0.0877
# Epoch 10/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9891 - loss: 0.0434 - val_accuracy: 0.9888 - val_loss: 0.0891
# Epoch 11/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9948 - loss: 0.0206 - val_accuracy: 0.9888 - val_loss: 0.0925
# Epoch 12/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9938 - loss: 0.0226 - val_accuracy: 0.9888 - val_loss: 0.1105
# Epoch 13/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 18s 17ms/step - accuracy: 0.9952 - loss: 0.0206 - val_accuracy: 0.9898 - val_loss: 0.1016
# Epoch 14/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 17s 17ms/step - accuracy: 0.9956 - loss: 0.0177 - val_accuracy: 0.9902 - val_loss: 0.1027
# Epoch 15/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 19s 18ms/step - accuracy: 0.9944 - loss: 0.0208 - val_accuracy: 0.9893 - val_loss: 0.1044
# Epoch 16/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 19s 18ms/step - accuracy: 0.9951 - loss: 0.0213 - val_accuracy: 0.9888 - val_loss: 0.1200
# Epoch 17/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 18s 17ms/step - accuracy: 0.9954 - loss: 0.0160 - val_accuracy: 0.9902 - val_loss: 0.1070
# Epoch 18/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 17s 17ms/step - accuracy: 0.9973 - loss: 0.0090 - val_accuracy: 0.9893 - val_loss: 0.1266
# Epoch 19/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9949 - loss: 0.0168 - val_accuracy: 0.9902 - val_loss: 0.0967
# Epoch 20/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 17s 17ms/step - accuracy: 0.9985 - loss: 0.0080 - val_accuracy: 0.9898 - val_loss: 0.1166
# Epoch 21/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 17s 17ms/step - accuracy: 0.9967 - loss: 0.0115 - val_accuracy: 0.9902 - val_loss: 0.1062
# Epoch 22/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 17s 17ms/step - accuracy: 0.9978 - loss: 0.0052 - val_accuracy: 0.9907 - val_loss: 0.1129
# Epoch 23/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9984 - loss: 0.0073 - val_accuracy: 0.9912 - val_loss: 0.1216
# Epoch 24/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 17s 17ms/step - accuracy: 0.9970 - loss: 0.0159 - val_accuracy: 0.9898 - val_loss: 0.1246
# Epoch 25/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9984 - loss: 0.0038 - val_accuracy: 0.9917 - val_loss: 0.1163
# Epoch 26/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 17s 16ms/step - accuracy: 0.9994 - loss: 0.0024 - val_accuracy: 0.9912 - val_loss: 0.1084
# Epoch 27/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 16s 16ms/step - accuracy: 0.9987 - loss: 0.0044 - val_accuracy: 0.9898 - val_loss: 0.1404
# Epoch 28/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9987 - loss: 0.0051 - val_accuracy: 0.9912 - val_loss: 0.1178
# Epoch 29/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 5s 4ms/step - accuracy: 0.9989 - loss: 0.0039 - val_accuracy: 0.9912 - val_loss: 0.1229
# Epoch 30/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9990 - loss: 0.0051 - val_accuracy: 0.9907 - val_loss: 0.1252
# Epoch 31/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9977 - loss: 0.0075 - val_accuracy: 0.9893 - val_loss: 0.1545
# Epoch 32/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9983 - loss: 0.0061 - val_accuracy: 0.9898 - val_loss: 0.1497
# Epoch 33/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9991 - loss: 0.0045 - val_accuracy: 0.9912 - val_loss: 0.1349
# Epoch 34/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9988 - loss: 0.0036 - val_accuracy: 0.9912 - val_loss: 0.1560
# Epoch 35/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9993 - loss: 0.0022 - val_accuracy: 0.9912 - val_loss: 0.1539
# Epoch 36/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9998 - loss: 8.7352e-04 - val_accuracy: 0.9907 - val_loss: 0.1434
# Epoch 37/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9998 - loss: 8.5121e-04 - val_accuracy: 0.9907 - val_loss: 0.1471
# Epoch 38/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9990 - loss: 0.0031 - val_accuracy: 0.9907 - val_loss: 0.1307
# Epoch 39/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9995 - loss: 0.0026 - val_accuracy: 0.9922 - val_loss: 0.1512
# Epoch 40/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9990 - loss: 0.0053 - val_accuracy: 0.9907 - val_loss: 0.1584
# Epoch 41/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9995 - loss: 0.0015 - val_accuracy: 0.9912 - val_loss: 0.1689
# Epoch 42/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 1.0000 - loss: 2.2936e-04 - val_accuracy: 0.9907 - val_loss: 0.1700
# Epoch 43/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9998 - loss: 7.7954e-04 - val_accuracy: 0.9917 - val_loss: 0.1661
# Epoch 44/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9987 - loss: 0.0058 - val_accuracy: 0.9917 - val_loss: 0.1618
# Epoch 45/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9991 - loss: 0.0064 - val_accuracy: 0.9912 - val_loss: 0.1626
# Epoch 46/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9996 - loss: 0.0010 - val_accuracy: 0.9912 - val_loss: 0.1698
# Epoch 47/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 5s 5ms/step - accuracy: 0.9998 - loss: 0.0011 - val_accuracy: 0.9917 - val_loss: 0.1664
# Epoch 48/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9996 - loss: 0.0026 - val_accuracy: 0.9917 - val_loss: 0.1772
# Epoch 49/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 9s 5ms/step - accuracy: 0.9978 - loss: 0.0094 - val_accuracy: 0.9912 - val_loss: 0.1896
# Epoch 50/50
# 1025/1025 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.9998 - loss: 0.0027 - val_accuracy: 0.9912 - val_loss: 0.1964

# %%
loss, accuracy = model.evaluate(X_test_pad, y_test_cat)

print("Test Accuracy:", accuracy)
# Out:
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9912 - loss: 0.1964
# Test Accuracy: 0.9912195205688477

# %%
model.save("gru_chatbot_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
import pickle

with open("tokenizer.pkl", "wb") as file:
    pickle.dump(tokenizer, file)

# %%
with open("label_encoder.pkl", "wb") as file:
    pickle.dump(encoder, file)

# %%
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# %%
def predict_intent(text):
    
    sequence = tokenizer.texts_to_sequences([text])

    padded = pad_sequences(
        sequence,
        maxlen=max_length,
        padding="post"
    )

    prediction = model.predict(padded, verbose=0)

    confidence = np.max(prediction)

    predicted_class = np.argmax(prediction)

    tag = encoder.inverse_transform(
        [predicted_class]
    )[0]

    return tag, confidence

# %%
while True:

    msg = input("You: ")

    if msg.lower() == "quit":
        break

    tag, confidence = predict_intent(msg)

    print("Tag:", tag)
    print("Confidence:", confidence)
# Out:
# You:  hostel fee
# Tag: hostel
# Confidence: 1.0
# You:
# Tag: greeting
# Confidence: 0.9991117
# You:  bye
# Tag: goodbye
# Confidence: 1.0
# You:  canteen
# Tag: canteen
# Confidence: 0.999998
# You:  quit

# %%
import random

def get_response(tag):

    for intent in data["intents"]:

        if intent["tag"] == tag:

            return random.choice(intent["responses"])

    return "I don't understand."

# %%
while True:

    msg = input("You: ")

    if msg.lower() == "quit":
        break

    tag, confidence = predict_intent(msg)

    response = get_response(tag)

    print("Bot:", response)
    print("Confidence:", round(confidence, 4))
# Out:
# You:  quit
